# %% [markdown]
# # 02 — Model Comparison
#
# How do different LLMs compare in their restaurant recommendations?
#
# **Questions this notebook answers:**
# - Which restaurants do all models agree on?
# - Which are model-specific recommendations?
# - How different are parametric vs search-augmented responses?
# - Do models have different cuisine or price biases?

# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
import plotly.express as px
from src.db import init_db, get_query_results, get_restaurant_mentions

# %%
conn = init_db()
# TODO: Model comparison analysis after Phase 2 parsing
