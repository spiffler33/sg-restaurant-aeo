# %% [markdown]
# # 03 — Signal Analysis
#
# What signals predict whether a restaurant gets recommended by LLMs?
#
# **Questions this notebook answers:**
# - Does Michelin status correlate with recommendation frequency?
# - What role do Google Maps ratings and review counts play?
# - Is there a measurable bias toward certain cuisines, price points, or areas?
# - How does web presence (media coverage, website quality) affect visibility?

# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
import plotly.express as px
from src.db import init_db, get_mention_counts

# %%
conn = init_db()
# TODO: Signal analysis after Phase 3 ground truth collection
